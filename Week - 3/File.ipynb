# %%
file = open("sample.txt","r")
print(file.read())
# Out:
# Hii Hariharan
# Welcome to Python Learning
# Oops concept
# Python Classes

# %%
f = open("Newfile.txt",'w')
f.write('Created a Newfile\n')
f.write('New contents are added\n')
f.write('New changes')
# Out:
# 11

# %%
with open('Newfile.txt', 'r') as f:
    print(f.read())
# Out:
# Created a Newfile
# New contents are added
# New changes

# %%
with open('Newfile.txt', 'a') as f:
    f.write('\nFile Handling\n')
    f.write('Exception Handling')

# %%
with open('Newfile.txt', 'r') as f:
    print(f.read())
# Out:
# Created a Newfile
# New contents are added
# New changes
# File Handling
# Exception Handling

# %%
with open("sample.txt", 'r') as file:
    print(file.readlines())
# Out:
# ['Hii Hariharan \n', 'Welcome to Python Learning\n', 'Oops concept \n', 'Python Classes']

# %%
with open("sample.txt", 'r') as file:
    print(file.readline())
# Out:
# Hii Hariharan

# %%
file = open('sample.txt', 'a')
lines = [
    "\nPython",
    "\nSQL",
    "\nJavaScript"
]

file.writelines(lines)

# %%
with open('sample.txt', 'r') as file:
    print(file.read())
# Out:
# Hii Hariharan
# Welcome to Python Learning
# Oops concept
# Python Classes
# Python
# SQL
# JavaScript
